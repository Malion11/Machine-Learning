# %% [markdown]
# ### Hierarchal Clustering
# * Use AgglomerativeClustering function to  to cluster the above data
# * In the  AgglomerativeClustering change the following parameters
#     * Affinity (use euclidean, manhattan and cosine)
#     * Linkage( use average and single )
#     * Distance_threshold (try different)
# * For each of these trials plot the Dendograph , calculate the silhouette_score and display the resulting clusters
# * Find the set of paramters that would find result in the best silhouette_score and store this score for later comparison with other clustering techniques.
# * Record your observation

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from sklearn import metrics
def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
###Euclidean affinity and average linkage

# %%
clustering_euc_avg_1 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "average", distance_threshold= 1, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_avg_1.fit(Multi_blob_Data).labels_)
# Out:
# 0.32384977908646284

# %%
plot_dendrogram(clustering_euc_avg_1, labels=clustering_euc_avg_1.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_avg_1.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_euc_avg_3 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "average", distance_threshold= 3, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_avg_3.fit(Multi_blob_Data).labels_)
# Out:
# 0.35500586075131524

# %%
plot_dendrogram(clustering_euc_avg_3, labels=clustering_euc_avg_3.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_avg_3.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_euc_avg_5 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "average", distance_threshold= 5, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_avg_5.fit(Multi_blob_Data).labels_)
# Out:
# 0.433187948807373

# %%
plot_dendrogram(clustering_euc_avg_5, labels=clustering_euc_avg_5.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_avg_5.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_euc_avg_8 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "average", distance_threshold= 8, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_avg_8.fit(Multi_blob_Data).labels_)
# Out:
# 0.4716908069861964

# %%
plot_dendrogram(clustering_euc_avg_8, labels=clustering_euc_avg_8.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_avg_8.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
###using ecclidean affinity and average linakge, the best distance threshold was 8 according to the silhouette score ()

# %%
###Euclidean affinity and single linkage

# %%
clustering_euc_sng_1 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "single", distance_threshold= 1, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_sng_1.fit(Multi_blob_Data).labels_)
# Out:
# -0.14944154607335855

# %%
plot_dendrogram(clustering_euc_sng_1, labels=clustering_euc_sng_1.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_sng_1.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_euc_sng_2 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "single", distance_threshold= 2, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_sng_2.fit(Multi_blob_Data).labels_)
# Out:
# 0.3218066204847175

# %%
plot_dendrogram(clustering_euc_sng_2, labels=clustering_euc_sng_2.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_sng_2.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_euc_sng_5 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "single", distance_threshold= 0.5, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_sng_5.fit(Multi_blob_Data).labels_)
# Out:
# -0.4596550259264691

# %%
plot_dendrogram(clustering_euc_sng_5, labels=clustering_euc_sng_5.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_sng_5.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_euc_sng_8 = AgglomerativeClustering(n_clusters = None, affinity = "euclidean", linkage = "single", distance_threshold= 0.8, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_euc_sng_8.fit(Multi_blob_Data).labels_)
# Out:
# -0.41297230277201613

# %%
plot_dendrogram(clustering_euc_sng_8, labels=clustering_euc_sng_8.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_euc_sng_8.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
###Using Euclidean affinity and single linkage, the best distance threshold is 2

# %%
###Manhattan affinity and average linkage

# %%
clustering_man_avg_1 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "average", distance_threshold= 1, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_avg_1.fit(Multi_blob_Data).labels_)
# Out:
# 0.34093328073765305

# %%
plot_dendrogram(clustering_man_avg_1, labels=clustering_man_avg_1.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_avg_1.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_man_avg_3 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "average", distance_threshold= 3, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_avg_3.fit(Multi_blob_Data).labels_)
# Out:
# 0.2962118593103159

# %%
plot_dendrogram(clustering_man_avg_3, labels=clustering_man_avg_3.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_avg_3.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_man_avg_5 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "average", distance_threshold= 5, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_avg_5.fit(Multi_blob_Data).labels_)
# Out:
# 0.399558543983381

# %%
plot_dendrogram(clustering_man_avg_5, labels=clustering_man_avg_5.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_avg_5.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_man_avg_8 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "average", distance_threshold= 8, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_avg_8.fit(Multi_blob_Data).labels_)
# Out:
# 0.38321869346484616

# %%
plot_dendrogram(clustering_man_avg_8, labels=clustering_man_avg_8.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_avg_8.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
###the best distance threshold using manhattan affinity and average linkage is 5

# %%
###Manhattan affinity and single linkage

# %%
clustering_man_sng_1 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "single", distance_threshold= 1, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_sng_1.fit(Multi_blob_Data).labels_)
# Out:
# -0.4080040507331309

# %%
plot_dendrogram(clustering_man_sng_1, labels=clustering_man_sng_1.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_sng_1.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_man_sng_2 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "single", distance_threshold= 2, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_sng_2.fit(Multi_blob_Data).labels_)
# Out:
# 0.14871638406533946

# %%
plot_dendrogram(clustering_man_sng_2, labels=clustering_man_sng_2.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_sng_2.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_man_sng_5 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "single", distance_threshold= 0.5, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_sng_5.fit(Multi_blob_Data).labels_)
# Out:
# -0.4810336379611459

# %%
plot_dendrogram(clustering_man_sng_5, labels=clustering_man_sng_5.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_sng_5.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_man_sng_8 = AgglomerativeClustering(n_clusters = None, affinity = "manhattan", linkage = "single", distance_threshold= 0.8, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_man_sng_8.fit(Multi_blob_Data).labels_)
# Out:
# -0.42481094321410856

# %%
plot_dendrogram(clustering_man_sng_8, labels=clustering_man_sng_8.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_man_sng_8.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
###Using manhattan affinity and single linkage, the best distance threshold is 2

# %%
###Cosine affinity and average linkage

# %%
clustering_cos_avg_1 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "average", distance_threshold= 1, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_cos_avg_1.fit(Multi_blob_Data).labels_)
# Out:
# 0.35251834131557364

# %%
plot_dendrogram(clustering_cos_avg_1, labels=clustering_cos_avg_1.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_avg_1.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_cos_avg_3 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "average", distance_threshold= 0.3, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_cos_avg_3.fit(Multi_blob_Data).labels_)
# Out:
# 0.24927357773894548

# %%
plot_dendrogram(clustering_cos_avg_3, labels=clustering_cos_avg_3.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_avg_3.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_cos_avg_5 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "average", distance_threshold= 0.5, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_cos_avg_5.fit(Multi_blob_Data).labels_)
# Out:
# 0.28022113778340446

# %%
plot_dendrogram(clustering_cos_avg_5, labels=clustering_cos_avg_5.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_avg_5.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_cos_avg_8 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "average", distance_threshold= 0.8, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_cos_avg_8.fit(Multi_blob_Data).labels_)
# Out:
# 0.13500755155170832

# %%
plot_dendrogram(clustering_cos_avg_8, labels=clustering_cos_avg_8.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_avg_8.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
###Using cosine affinity and average linkage, the best distance threshold is 1

# %%
###Cosine affinity and single linkage

# %%
clustering_cos_sng_1 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "single", distance_threshold= 0.1, compute_full_tree= True)

# %%
plot_dendrogram(clustering_cos_sng_1, labels=clustering_cos_sng_1.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_sng_1.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_cos_sng_2 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "single", distance_threshold= 2, compute_full_tree= True)

# %%
plot_dendrogram(clustering_cos_sng_2, labels=clustering_cos_sng_2.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_sng_2.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_cos_sng_5 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "single", distance_threshold= 0.5, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_cos_sng_5.fit(Multi_blob_Data).labels_)

# %%
plot_dendrogram(clustering_cos_sng_5, labels=clustering_cos_sng_5.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_sng_5.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
clustering_cos_sng_8 = AgglomerativeClustering(n_clusters = None, affinity = "cosine", linkage = "single", distance_threshold= 0.8, compute_full_tree= True)

# %%
metrics.silhouette_score(Multi_blob_Data, clustering_cos_sng_8.fit(Multi_blob_Data).labels_)

# %%
plot_dendrogram(clustering_cos_sng_8, labels=clustering_cos_sng_8.fit(Multi_blob_Data).labels_)
plt.show()

# %%
plt.scatter(Multi_blob_Data[:, 0], Multi_blob_Data[:, 1], c=clustering_cos_sng_8.fit_predict(Multi_blob_Data), cmap="rainbow")

# %%
#####
